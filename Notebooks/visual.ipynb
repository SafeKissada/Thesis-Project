# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATA_PATH = r"D:\0PROJECT\thesis\docs\saved\Metadata_MasterData.csv"
df = pd.read_csv(DATA_PATH)

# %%
display(df)
# Out:
#                                                 filepath  class_name  \
# 0            D:\0PROJECT\thesis\data\raw\defect\(1).jpeg      defect
# 1           D:\0PROJECT\thesis\data\raw\defect\(10).jpeg      defect
# 2         D:\0PROJECT\thesis\data\raw\defect\(1000).jpeg      defect
# 3          D:\0PROJECT\thesis\data\raw\defect\(100).jpeg      defect
# 4         D:\0PROJECT\thesis\data\raw\defect\(1001).jpeg      defect
# ...                                                  ...         ...
# 34114  D:\0PROJECT\thesis\data\raw\false call\(9995)....  false call
# 34115  D:\0PROJECT\thesis\data\raw\false call\(9996)....  false call
# 34116  D:\0PROJECT\thesis\data\raw\false call\(9997)....  false call
# 34117  D:\0PROJECT\thesis\data\raw\false call\(9998)....  false call
# 34118  D:\0PROJECT\thesis\data\raw\false call\(9999)....  false call
#
#           filename   ext  file_size  is_corrupt  \
# 0         (1).jpeg  jpeg       8223       False
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34119 entries, 0 to 34118
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   filepath             34119 non-null  str
#  1   class_name           34119 non-null  str
#  2   filename             34119 non-null  str
#  3   ext                  34119 non-null  str
#  4   file_size            34119 non-null  int64
#  5   is_corrupt           34119 non-null  bool
#  6   md5_hash             34119 non-null  str
#  7   width                34119 non-null  int64
#  8   height               34119 non-null  int64
#  9   pixel                34119 non-null  int64
#  10  aspect_ratio         34119 non-null  float64
#  11  red_mean             34119 non-null  float64
#  12  green_mean           34119 non-null  float64
#  13  blue_mean            34119 non-null  float64
#  14  red_std              34119 non-null  float64
# ...
